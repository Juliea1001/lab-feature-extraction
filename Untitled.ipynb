# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
data_cat=pd.read_csv('../lab-feature-extraction/files_for_lab/Data_Categorical.csv') 
data_cat
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type        policy  \
# ...

# %%
data = pd.read_csv('../lab-cleaning-numerical-data/files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv') 
data
# for the time variable I have to read the original dataframe from the csv file in the beginning
# since I droped the column (effective_to_date) in the categorical data.
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
categoricals = data.select_dtypes(np.object)
categoricals.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1  QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2  AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3  WW63253  California       No     Basic  Bachelor           1/20/11
# 4  HB64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
for col in data_cat.columns:
    plt.figure(figsize=[10,8])
    n, bins, patches = plt.hist(data_cat[col],50,  density=False, facecolor='y', alpha=1, stacked=True)
    plt.xlabel(col)
    plt.ylabel('number of counts')
    plt.title(col)
    
    plt.show()
# column 'policy' allready contains the 'policy_type' information, but it is kind of nice
# having the policy_type by it's own for the overview. So I keep policy_type. I rather would
# drop the column policy, since I don't understand the code (L1-L3). But I keep it, in case
# somthing reveals about a corellation to that code.

#most of the customers are from California. 
#The majority gave no response.
# the coverage is mostly 'Basic'.
# there are reasonable a minority of customers with master and even doctor.
# there are aproximately 2400/9134 = 26% of the customers unemployed!
# the gender of the customers is nearly even with a little mor female person.
# the majority of the customers lives in suburban area. The customers living in rural or urban
# area are about the same amount.
# there is a bigger number of married customer (about 5300/9134= 58%).
#About 74% of the insured cars are personal cars and not corporated (22%)or special cars.
# the code L3 is more often in the policies before L2 and the L1.
# the more often sales channel is via agents, followed by branch. Call Center is still more
# often then the smallest sales channel via the web.
# Four door car is the most often insured vehicle (about 50%). 
# SUVs place about 22% of the insured cars.
# 70% of the insured cars are medsized cars. Large cars place only about 11% of the insured 
# vehicles.

# %%
plt.figure(figsize=[10,8])
n, bins, patches = plt.hist(data['Effective To Date'],50,  density=False, facecolor='y', alpha=1, stacked=True)
plt.xlabel('Effective To Date')
plt.ylabel('number of counts')
plt.title('Effective To Date')

plt.show()

# %%
DatePlusWeekday=[]
#data['Effective To Date'].value_counts()
for i in data['Effective To Date']:
    j = pd.to_datetime(i, format ="%m/%d/%y")
    DatePlusWeekday.append(pd.to_datetime(j, format='%m/%d/%y').strftime('%m/%d/%y/%A'))
data['effective_to_date_plus_weekday']=DatePlusWeekday

data['effective_to_date_plus_weekday'].value_counts()
# Out:
# 01/10/11/Monday       195
# 01/27/11/Thursday     194
# 02/14/11/Monday       186
# 01/26/11/Wednesday    181
# 01/17/11/Monday       180
# 01/19/11/Wednesday    179
# 01/03/11/Monday       178
# 01/31/11/Monday       178
# 01/20/11/Thursday     173
# 01/28/11/Friday       169
# 02/26/11/Saturday     169
# 02/19/11/Saturday     168
# 02/27/11/Sunday       167
# 01/05/11/Wednesday    167
# 01/11/11/Tuesday      166
# 02/04/11/Friday       164
# 02/28/11/Monday       161
# 02/10/11/Thursday     161
# 01/29/11/Saturday     160
# 01/21/11/Friday       160
# 01/02/11/Sunday       160
# 02/22/11/Tuesday      158
# 02/03/11/Thursday     158
# 02/05/11/Saturday     158
# 02/07/11/Monday       157
# 02/12/11/Saturday     156
# 01/23/11/Sunday       155
# 02/01/11/Tuesday      154
# 01/18/11/Tuesday      154
# 01/15/11/Saturday     153
# 01/14/11/Friday       152
# 01/07/11/Friday       151
# 01/25/11/Tuesday      151
# 02/11/11/Friday       151
# 02/02/11/Wednesday    149
# ...

# %%
date_frequency=data['effective_to_date_plus_weekday'].value_counts().sort_index()

date_frequency_high=date_frequency[(date_frequency>158)]
plt.figure(figsize=[10,8])
date_frequency_high.plot(kind='bar')
# plot of higher counts days (>158), but I don't see a pattern, why they have more counts.
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=[10,8])
n, bins, patches = plt.hist((data_filtered,50,  density=False, facecolor='g', alpha=1, stacked=True)
plt.xlabel('Effective To Date')
plt.ylabel('number of counts')
plt.title('Effective To Date')
# Out:
#   File "<ipython-input-9-ad333f6beffe>", line 2
#     n, bins, patches = plt.hist((data_filtered,50,  density=False, facecolor='g', alpha=1, stacked=True)
#                                                            ^
# SyntaxError: invalid syntax

# %%
DateWeekday=[]
#data['Effective To Date'].value_counts()
for i in data['Effective To Date']:
    j = pd.to_datetime(i, format ="%m/%d/%y")
    DateWeekday.append(pd.to_datetime(j, format='%m/%d/%y').strftime('%w'))
data['effective_to_date_weekday']=DateWeekday

data['effective_to_date_weekday'].value_counts().sort_index()
# Out:
# 0    1330
# 1    1530
# 2    1162
# 3    1221
# 4    1249
# 5    1245
# 6    1397
# Name: effective_to_date_weekday, dtype: int64

# %%
data['effective_to_date_weekday'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Weekday (0=sunday...)')
plt.ylabel('number of counts')
plt.title('Effective_to_date_Weekday')
#0 being sunday, followed by 1= monday...

#monday has the most counts, followed by the weekend(saturday and sunday)
# Out:
# Text(0.5, 1.0, 'Effective_to_date_Weekday')

# %%
for i in (data['Effective To Date']):
    i = pd.to_datetime(i, format ="%m/%d/%y")
    print(i.day_name())
# Out:
# Thursday
# Monday
# Saturday
# Thursday
# Thursday
# Tuesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Monday
# Thursday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Sunday
# Friday
# Saturday
# Friday
# Wednesday
# Thursday
# Saturday
# Saturday
# Monday
# Saturday
# Wednesday
# Monday
# Monday
# Saturday
# Tuesday
# Tuesday
# Sunday
# Saturday
# Saturday
# Sunday
# Tuesday
# Monday
# Tuesday
# Tuesday
# Friday
# Tuesday
# Wednesday
# Tuesday
# Monday
# Sunday
# Monday
# Tuesday
# Monday
# Tuesday
# Monday
# Wednesday
# Monday
# Saturday
# Sunday
# Wednesday
# Friday
# Monday
# Sunday
# Saturday
# Saturday
# Thursday
# Sunday
# Monday
# Wednesday
# Monday
# Thursday
# Sunday
# Thursday
# Friday
# Saturday
# Friday
# Tuesday
# Friday
# Tuesday
# Tuesday
# Sunday
# Sunday
# Wednesday
# Saturday
# Thursday
# Sunday
# Thursday
# Monday
# Tuesday
# Saturday
# Tuesday
# Saturday
# Thursday
# Sunday
# Monday
# Thursday
# Monday
# Thursday
# Tuesday
# Wednesday
# ...

# %%
DateWeek=[]
#data['Effective To Date'].value_counts()
for i in data['Effective To Date']:
    j = pd.to_datetime(i, format ="%m/%d/%y")
    DateWeek.append(pd.to_datetime(j, format='%m/%d/%y').strftime('%V'))
data['effective_to_date_week']=DateWeek

data['effective_to_date_week'].value_counts().sort_index()
# Out:
# 01    1049
# 02    1079
# 03    1137
# 04    1147
# 05    1105
# 06    1035
# 07    1040
# 08    1073
# 09     161
# 52     308
# Name: effective_to_date_week, dtype: int64

# %%
data['effective_to_date_week'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Week')
plt.ylabel('number of counts')
plt.title('Effective_to_date_Week')
# Out:
# Text(0.5, 1.0, 'Effective_to_date_Week')

# %%
DateMonth=[]
#data['Effective To Date'].value_counts()
for i in data['Effective To Date']:
    j = pd.to_datetime(i, format ="%m/%d/%y")
    DateMonth.append(pd.to_datetime(j, format='%m/%d/%y').strftime('%B'))
data['effective_to_date_Month']=DateMonth

data['effective_to_date_Month'].value_counts()
# Out:
# January     4898
# February    4236
# Name: effective_to_date_Month, dtype: int64

# %%
data['effective_to_date_Month'].value_counts().plot(kind='bar')
plt.xlabel('month')
plt.ylabel('number of counts')
plt.title('Effective_to_date_Month')
#january has more counts then february
# Out:
# Text(0.5, 1.0, 'Effective_to_date_Month')
